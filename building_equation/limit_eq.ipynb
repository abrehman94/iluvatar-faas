# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np

fig = plt.figure()
ax = fig.add_subplot(projection='3d')

x = np.linspace(-5, 5, 50)
y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

slowdown = np.linspace(1, 30, 50)
concur = np.linspace(0, 10, 50)
SLW, CNC = np.meshgrid(slowdown, concur)
#Z = np.sin(np.sqrt(X**2 + Y**2))

def calc_limit( slowdown, concur ):
    return concur/slowdown + 1

def calc_limit( slowdown, concur ):
    return concur/slowdown + int(slowdown//3) + 1 

climitv = np.vectorize( calc_limit )
LIMIT = climitv( SLW, CNC )

ax.plot_surface(SLW, CNC, LIMIT)
ax.set_xlabel('slowdown')
ax.set_xlim( 0 )
ax.set_ylabel('concur')
ax.set_ylim( 0 )
ax.set_zlabel('limit')
ax.set_zlim( 0 )
ax.set_title('')

plt.show()
# Out:
# /tmp/ipykernel_826945/3705719058.py:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig = plt.figure()
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
